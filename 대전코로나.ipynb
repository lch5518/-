# %% [markdown]
# ## 코로나-19, 241번확진자 동선(대전)

# %% [markdown]
# 대전 대동 : 36.329791, 127.443355
#
# |loc|lat|lon|
# |---|---|---|
# |대전역|	36.332974|	127.434325|
# |대전역_버스정류장|	36.330967|	127.432194|
# |불난뚱땡이|	36.335857|	127.449256|
# |매직코인노래연습장|	36.338077|	127.447722|
# |우송대학교서캠퍼스IT교육센터|	36.339252|	127.449751|
# |우송대 W18건물|	36.338261|	127.444983|
# |손이가짜장|	36.336246|	127.446566|
# |1983더그레이|	36.33957|	127.44914|
# |우송대_버스정류장|	36.33841|	127.447434|
# |레스모아_중앙점|	36.329577|	127.427874|
# |토마토|	36.328303|	127.427376|
# |인생네컷|	36.32818|	127.427902|
# |에머필|	36.32755|	127.427568|
# |섹시쿠키|	36.327854|	127.427411|
# |케이스닥터|	36.328786|	127.427866|
# |은행동지하상가|	36.328643|	127.425942|
# |은행동_버스정류장|	36.328759|	127.426656|
# |매직코인노래연습장|	36.338077|	127.447722|
# |아지트PC방|	36.33428|	127.445337|
# |케이마트|	36.337509|	127.44805|
# |동구보건소|	36.312057|	127.454784|
# |우리동네DC아울렛|	36.341067|	127.449524|
# |우체국|	36.339848|	127.449251|

# %%
latlon = [[36.332974,127.434325],
[36.330967, 127.432194],
[36.335857, 127.449256],
[36.338077, 127.447722],
[36.339252,127.449751],
[36.338261,127.444983],
[36.336246,127.446566],
[36.33957,127.44914],
[36.33841,127.447434],
[36.329577,127.427874],
[36.328303,127.427376],
[36.32818,127.427902],
[36.32755,127.427568],
[36.327854,127.427411],
[36.328786,127.427866],
[36.328643,127.425942],
[36.328759,127.426656],
[36.338077,127.447722],
[36.33428,127.445337],
[36.337509,127.44805],
[36.312057,127.454784],
[36.341067,127.449524],
[36.339848,127.449251],
]

# %%
import folium

# %%
from folium.plugins import HeatMap

# %%
m = folium.Map(
    location = [36.329791, 127.443355],
    zoom_start = 15,
    tiles = 'COVID-19'
)
HeatMap(latlon).add_to(m)

# %%
m.save('대전_241번확진자.html')
